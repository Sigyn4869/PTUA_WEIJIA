# %% [markdown]
# # Data Description
#
# In this dataset, you will find a refactorised version of the data from the London data store, that contains the energy consumption readings for a sample of 5,567 London Households that took part in the UK Power Networks led Low Carbon London project between November 2011 and February 2014. The data from the smart meters seems associated only to the electrical consumption.
#
# There is 19 files in this dataset :
#
# informations_households.csv : this file that contains all the information on the households in the panel (their acorn group, their tariff) and in which block.csv.gz file their data are stored
#
# halfhourly_dataset.zip: Zip file that contains the block files with the half-hourly smart meter measurement
#
# daily_dataset.zip: Zip file that contains the block files with the daily information like the number of measures, minimum, maximum, mean, median, sum and std.
#
# acorn_details.csv : Details on the acorn groups and their profile of the people in the group, it's come from this xlsx spreadsheet.The first three columns are the attributes studied, the ACORN-X is the index of the attribute. At a national scale, the index is 100 if for one column the value is 150 it means that there are 1.5 times more people with this attribute in the ACORN group than at the national scale. You can find an explanation on the CACI website
#
# weather_daily_darksky.csv : that contains the daily data from darksky api. You can find more details about the parameters in the documentation of the api
#
# weather_hourly_darksky.csv : that contains the hourly data from darksky api. You can find more details about the parameters in the documentation of the api
#
# Inspiration
# For me some ideas to analyze the data:
#
# Segmentation of the consumption daily pattern
# Disaggregation of the electricity load curve
# Cross the consumption result and the acorn information
# Forecast the electricity consumption of a household, I wrote an article on this subject
# What if I add electrical heating system ? an EV battery system ?
# Forecast at a global scale (London consumption)
#
#
# 在本数据集中，您可以找到伦敦数据存储的重构版数据，其中包含 2011 年 11 月至 2014 年 2 月期间参与英国电力网络公司领导的低碳伦敦项目的 5567 户伦敦家庭的能源消耗读数样本。来自智能电表的数据似乎只与电力消耗相关联。
#
# 该数据集中有 19 个文件：
#
# informations_households.csv：该文件包含面板中住户的所有信息（他们的橡子组、他们的电价），以及他们的数据存储在哪个 block.csv.gz 文件中。
#
# halfhourly_dataset.zip： 包含智能电表半小时测量数据块文件的压缩文件
#
# daily_dataset.zip： Zip 文件，包含每日信息的块文件，如测量次数、最小值、最大值、平均值、中位数、总和和 std.
#
# acorn_details.csv：有关 acorn 小组及其小组成员概况的详细信息，来自此 xlsx 电子表格。前三列是所研究的属性，ACORN-X 是该属性的指数。在全国范围内，指数为 100，如果某一列的指数值为 150，则意味着 ACORN 群体中具有该属性的人数是全国范围内的 1.5 倍。您可以在 CACI 网站上找到相关解释
#
# weather_daily_darksky.csv : 包含来自 darksky api 的每日数据。有关参数的更多详情，请参阅 api 文档
#
# weather_hourly_darksky.csv : 包含来自 darksky api 的每小时数据。有关参数的更多详情，请参阅 api 文档。
#
# 灵感
# 我有一些分析数据的想法：
#
# 细分每日消费模式
# 分解电力负荷曲线
# 将用电结果与橡树果信息进行交叉分析
# 预测家庭用电量，我曾就此写过一篇文章
# 如果增加电加热系统和电动汽车电池系统会怎样？
# 全球范围的预测（伦敦的用电量）

# %% [markdown]
# This research aims to analyze and predict household energy consumption patterns in urban areas using a comprehensive dataset of smart meter readings from London.  The study will use Python as the primary tool for data analysis and model development. Key research components include:
#
# 1. Analyzing daily and hourly energy consumption patterns: Investigating energy usage trends across different households to identify common patterns and anomalies in daily or hourly energy consumption.
#
# 2. Neural Network-based prediction of household energy use: Developing a neural network model to predict household energy consumption. This model will integrate historical consumption data, weather conditions, and demographic information, aiming to assist in urban electricity grid management and planning.
#
# 3. Impact of weather conditions on energy consumption: Examining how different weather conditions influence energy usage patterns, utilizing detailed weather data collected through the Dark Sky API for the London area.
#
# The aim of the study is to provide valuable insights for urban planners, energy providers and policymakers to enable more efficient energy management and planning in urban environments.
#
#
# 本研究旨在利用伦敦智能电表读数的综合数据集，分析和预测城市地区的家庭能源消耗模式。 研究将使用 Python 作为数据分析和模型开发的主要工具。主要研究内容包括
#
# 1. 分析每日和每小时的能源消耗模式： 调查不同家庭的能源使用趋势，找出每日或每小时能源消耗的共同模式和异常现象。
#
# 2. 基于神经网络的家庭能源使用预测： 开发一个神经网络模型来预测家庭能源消耗。该模型将整合历史能耗数据、天气条件和人口信息，旨在协助城市电网管理和规划。
#
# 3. 天气条件对能源消耗的影响： 利用通过黑暗天空应用程序接口（Dark Sky API）收集的伦敦地区详细天气数据，研究不同天气条件如何影响能源使用模式。
#
# 该研究旨在为城市规划者、能源供应商和政策制定者提供有价值的见解，以便在城市环境中实现更高效的能源管理和规划。

# %%
import pandas as pd

# %%
# informations_households.csv：该文件包含面板中住户的所有信息（他们的橡子组、他们的电价），以及他们的数据存储在哪个 block.csv.gz 文件中。        
informations_households = pd.read_csv('archive/informations_households.csv')
informations_households
# Out:
#           LCLid stdorToU    Acorn Acorn_grouped       file
# 0     MAC005492      ToU   ACORN-        ACORN-    block_0
# 1     MAC001074      ToU   ACORN-        ACORN-    block_0
# 2     MAC000002      Std  ACORN-A      Affluent    block_0
# 3     MAC003613      Std  ACORN-A      Affluent    block_0
# 4     MAC003597      Std  ACORN-A      Affluent    block_0
# ...         ...      ...      ...           ...        ...
# 5561  MAC002056      Std  ACORN-U       ACORN-U  block_111
# 5562  MAC004587      Std  ACORN-U       ACORN-U  block_111
# 5563  MAC004828      Std  ACORN-U       ACORN-U  block_111
# 5564  MAC001704      ToU  ACORN-U       ACORN-U  block_111
# 5565  MAC002774      ToU  ACORN-U       ACORN-U  block_111
#
# [5566 rows x 5 columns]

# %% [markdown]
# 在统计数据表里，"Std"和"ToU"分别代表标准（Standard）和使用时间（Time of Use）电价。使用时间电价（TOU）是一种灵活的电价制度，旨在鼓励消费者在需求和能源成本较低的非高峰时段使用电力，以此帮助减少高峰时段的能源需求，促进电网的平衡，并有助于降低用户的电费支出

# %%
informations_households.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5566 entries, 0 to 5565
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LCLid          5566 non-null   object
#  1   stdorToU       5566 non-null   object
#  2   Acorn          5566 non-null   object
#  3   Acorn_grouped  5566 non-null   object
#  4   file           5566 non-null   object
# dtypes: object(5)
# memory usage: 217.5+ KB

# %%
unique_Acorn = informations_households['Acorn'].unique()
print(unique_Acorn)
unique_Acorn
# Out:
# ['ACORN-' 'ACORN-A' 'ACORN-B' 'ACORN-C' 'ACORN-D' 'ACORN-E' 'ACORN-F'
#  'ACORN-G' 'ACORN-H' 'ACORN-I' 'ACORN-J' 'ACORN-K' 'ACORN-L' 'ACORN-M'
#  'ACORN-N' 'ACORN-O' 'ACORN-P' 'ACORN-Q' 'ACORN-U']
# array(['ACORN-', 'ACORN-A', 'ACORN-B', 'ACORN-C', 'ACORN-D', 'ACORN-E',
#        'ACORN-F', 'ACORN-G', 'ACORN-H', 'ACORN-I', 'ACORN-J', 'ACORN-K',
#        'ACORN-L', 'ACORN-M', 'ACORN-N', 'ACORN-O', 'ACORN-P', 'ACORN-Q',
#        'ACORN-U'], dtype=object)

# %% [markdown]
# Acorn_grouped:['ACORN-'缺失值 'Affluent'富裕的 'Comfortable'舒适的 'Adversity'困难的 'ACORN-U'无法分类或未知数据，可能因为数据缺失或不适用于任何已定义的类别]

# %%
unique_Acorn_grouped = informations_households['Acorn_grouped'].unique()
print(unique_Acorn_grouped)
unique_Acorn_grouped
# Out:
# ['ACORN-' 'Affluent' 'Comfortable' 'Adversity' 'ACORN-U']
# array(['ACORN-', 'Affluent', 'Comfortable', 'Adversity', 'ACORN-U'],
#       dtype=object)

# %%
# daily_dataset.zip: Zip 文件，包含每日信息的块文件，如测量次数、最小值、最大值、平均值、中位数、总和和 std。
# 一个示例文件 block_0.csv
daily_block_0 = pd.read_csv('archive/daily_dataset/daily_dataset/block_0.csv')
daily_block_0
# Out:
#            LCLid         day  energy_median  energy_mean  energy_max  \
# 0      MAC000002  2012-10-12         0.1385     0.154304       0.886
# 1      MAC000002  2012-10-13         0.1800     0.230979       0.933
# 2      MAC000002  2012-10-14         0.1580     0.275479       1.085
# 3      MAC000002  2012-10-15         0.1310     0.213688       1.164
# 4      MAC000002  2012-10-16         0.1450     0.203521       0.991
# ...          ...         ...            ...          ...         ...
# 25569  MAC005492  2014-02-24         0.1690     0.175042       0.378
# 25570  MAC005492  2014-02-25         0.1550     0.160792       0.545
# 25571  MAC005492  2014-02-26         0.1490     0.178542       0.687
# 25572  MAC005492  2014-02-27         0.1140     0.146167       0.478
# 25573  MAC005492  2014-02-28         0.0880     0.088000       0.088
#
#        energy_count  energy_std  energy_sum  energy_min
# 0                46    0.196034       7.098       0.000
# ...

# %%
daily_block_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25574 entries, 0 to 25573
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LCLid          25574 non-null  object
#  1   day            25574 non-null  object
#  2   energy_median  25574 non-null  float64
#  3   energy_mean    25574 non-null  float64
#  4   energy_max     25574 non-null  float64
#  5   energy_count   25574 non-null  int64
#  6   energy_std     25496 non-null  float64
#  7   energy_sum     25574 non-null  float64
#  8   energy_min     25574 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 1.8+ MB

# %%
# halfhourly_dataset.zip: 包含智能电表半小时测量数据块文件的压缩文件
# 一个示例文件 block_0.csv
halfhourly_block_0 = pd.read_csv('archive/halfhourly_dataset/halfhourly_dataset/block_0.csv')
halfhourly_block_0
# Out:
#              LCLid                         tstp energy(kWh/hh)
# 0        MAC000002  2012-10-12 00:30:00.0000000             0
# 1        MAC000002  2012-10-12 01:00:00.0000000             0
# 2        MAC000002  2012-10-12 01:30:00.0000000             0
# 3        MAC000002  2012-10-12 02:00:00.0000000             0
# 4        MAC000002  2012-10-12 02:30:00.0000000             0
# ...            ...                          ...            ...
# 1222665  MAC005492  2014-02-27 22:00:00.0000000         0.182
# 1222666  MAC005492  2014-02-27 22:30:00.0000000         0.122
# 1222667  MAC005492  2014-02-27 23:00:00.0000000          0.14
# 1222668  MAC005492  2014-02-27 23:30:00.0000000         0.192
# 1222669  MAC005492  2014-02-28 00:00:00.0000000         0.088
#
# [1222670 rows x 3 columns]

# %%
halfhourly_block_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222670 entries, 0 to 1222669
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   LCLid           1222670 non-null  object
#  1   tstp            1222670 non-null  object
#  2   energy(kWh/hh)  1222670 non-null  object
# dtypes: object(3)
# memory usage: 28.0+ MB

# %%
daily_dataset = pd.read_csv('archive/daily_dataset.csv')
daily_dataset
# Out:
#              LCLid         day  energy_median  energy_mean  energy_max  \
# 0        MAC000131  2011-12-15         0.4850     0.432045       0.868
# 1        MAC000131  2011-12-16         0.1415     0.296167       1.116
# 2        MAC000131  2011-12-17         0.1015     0.189812       0.685
# 3        MAC000131  2011-12-18         0.1140     0.218979       0.676
# 4        MAC000131  2011-12-19         0.1910     0.325979       0.788
# ...            ...         ...            ...          ...         ...
# 3510428  MAC004977  2014-02-24         0.0950     0.118458       0.580
# 3510429  MAC004977  2014-02-25         0.0675     0.084208       0.176
# 3510430  MAC004977  2014-02-26         0.1080     0.120500       0.282
# 3510431  MAC004977  2014-02-27         0.0720     0.114062       0.431
# 3510432  MAC004977  2014-02-28         0.0970     0.097000       0.097
#
#          energy_count  energy_std  energy_sum  energy_min
# ...

# %%
daily_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3510433 entries, 0 to 3510432
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   LCLid          object
#  1   day            object
#  2   energy_median  float64
#  3   energy_mean    float64
#  4   energy_max     float64
#  5   energy_count   int64
#  6   energy_std     float64
#  7   energy_sum     float64
#  8   energy_min     float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 241.0+ MB

# %%
# ？
# 一个示例文件 block_0.csv
hhblock_blokc_0 = pd.read_csv('archive/hhblock_dataset/hhblock_dataset/block_0.csv')
block_0
# Out:
#            LCLid         day   hh_0   hh_1   hh_2   hh_3   hh_4   hh_5   hh_6  \
# 0      MAC000002  2012-10-13  0.263  0.269  0.275  0.256  0.211  0.136  0.161
# 1      MAC000002  2012-10-14  0.262  0.166  0.226  0.088  0.126  0.082  0.123
# 2      MAC000002  2012-10-15  0.192  0.097  0.141  0.083  0.132  0.070  0.130
# 3      MAC000002  2012-10-16  0.237  0.237  0.193  0.118  0.098  0.107  0.094
# 4      MAC000002  2012-10-17  0.157  0.211  0.155  0.169  0.101  0.117  0.084
# ...          ...         ...    ...    ...    ...    ...    ...    ...    ...
# 25281  MAC005492  2014-02-23  0.165  0.206  0.149  0.101  0.115  0.120  0.102
# 25282  MAC005492  2014-02-24  0.219  0.236  0.288  0.219  0.165  0.086  0.111
# 25283  MAC005492  2014-02-25  0.194  0.185  0.150  0.095  0.081  0.082  0.081
# 25284  MAC005492  2014-02-26  0.205  0.183  0.186  0.165  0.194  0.114  0.080
# 25285  MAC005492  2014-02-27  0.167  0.112  0.120  0.083  0.083  0.112  0.081
#
# ...

# %%
block_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25286 entries, 0 to 25285
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LCLid   25286 non-null  object
#  1   day     25286 non-null  object
#  2   hh_0    25286 non-null  float64
#  3   hh_1    25286 non-null  float64
#  4   hh_2    25286 non-null  float64
#  5   hh_3    25286 non-null  float64
#  6   hh_4    25286 non-null  float64
#  7   hh_5    25286 non-null  float64
#  8   hh_6    25286 non-null  float64
#  9   hh_7    25286 non-null  float64
#  10  hh_8    25286 non-null  float64
#  11  hh_9    25286 non-null  float64
#  12  hh_10   25286 non-null  float64
#  13  hh_11   25286 non-null  float64
#  14  hh_12   25286 non-null  float64
#  15  hh_13   25286 non-null  float64
#  16  hh_14   25286 non-null  float64
#  17  hh_15   25286 non-null  float64
#  18  hh_16   25286 non-null  float64
#  19  hh_17   25286 non-null  float64
# ...

# %%
# acorn_details.csv：有关 acorn 小组及其小组成员概况的详细信息，来自此 xlsx 电子表格。前三列是所研究的属性，ACORN-X 是该属性的指数。在全国范围内，指数为 100，如果某一列的指数值为 150，则意味着 ACORN 群体中具有该属性的人数是全国范围内的 1.5 倍。您可以在 CACI 网站上找到相关解释
acorn_details = pd.read_csv('archive/acorn_details.csv', encoding='windows-1252')
acorn_details
# Out:
#     MAIN CATEGORIES                CATEGORIES                  REFERENCE  \
# 0        POPULATION                       Age                    Age 0-4
# 1        POPULATION                       Age                   Age 5-17
# 2        POPULATION                       Age                  Age 18-24
# 3        POPULATION                       Age                  Age 25-34
# 4        POPULATION                       Age                  Age 35-49
# ..              ...                       ...                        ...
# 821    LEISURE TIME  Holiday Destination/Type                       Asia
# 822    LEISURE TIME  Holiday Destination/Type  Activity / Outdoor Sports
# 823    LEISURE TIME  Holiday Destination/Type                     Cruise
# 824    LEISURE TIME  Holiday Destination/Type                    Package
# 825    LEISURE TIME  Holiday Destination/Type              Self-catering
#
#      ACORN-A  ACORN-B  ACORN-C  ACORN-D  ACORN-E  ACORN-F  ACORN-G  ACORN-H  \
# ...

# %%
acorn_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826 entries, 0 to 825
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MAIN CATEGORIES  826 non-null    object
#  1   CATEGORIES       826 non-null    object
#  2   REFERENCE        825 non-null    object
#  3   ACORN-A          826 non-null    float64
#  4   ACORN-B          826 non-null    float64
#  5   ACORN-C          826 non-null    float64
#  6   ACORN-D          826 non-null    float64
#  7   ACORN-E          826 non-null    float64
#  8   ACORN-F          826 non-null    float64
#  9   ACORN-G          826 non-null    float64
#  10  ACORN-H          826 non-null    float64
#  11  ACORN-I          826 non-null    float64
#  12  ACORN-J          826 non-null    float64
#  13  ACORN-K          826 non-null    float64
#  14  ACORN-L          826 non-null    float64
#  15  ACORN-M          826 non-null    float64
# ...

# %%
unique_main_categories = acorn_details['MAIN CATEGORIES'].unique()
print('unique_main_categories:', unique_main_categories)

unique_categories = acorn_details['CATEGORIES'].unique()
print('unique_categories:', unique_categories)

unique_Reference = acorn_details['REFERENCE'].unique()
print('unique_Reference:', unique_Reference)
# Out:
# unique_main_categories: ['POPULATION' 'HOUSING' 'FAMILY' 'ECONOMY' 'EDUCATION' 'HEALTH'
#  'TRANSPORT' 'MARKETING CHANNELS' 'FINANCE' 'DIGITAL' 'SHOPPING' 'CONTACT'
#  'ENVIRONMENT' 'COMMUNITY SAFETY' 'LEISURE TIME']
# unique_categories: ['Age' 'Geography' 'Ethnicity' 'Country of Birth' 'Religion' 'House Type'
#  'House Tenure' 'House Size' 'House Value' 'Moving House' 'Structure'
#  'Children in household' 'Household Size' 'Economic Activity'
#  'NS Socio-Economic Classifications' 'Social Grade' 'Occupation'
#  'Highest Level of Qualifications (Adults)'
#  'England: Pupils at the end of KS1' 'England: Pupils at the end of KS2'
#  'England: Pupils at the end of KS4' 'Scotland: Pupils in the S4 cohort'
#  'Scotland: Pupils in the S5 cohort' 'Behaviours & Lifestyle'
#  'Travel To Work' 'Public Transport Accessibility Level' 'Car Ownership'
#  'Main Car Class' 'Channels Received' 'Future Responses'
#  'Household Annual Income' 'Financial Attitudes' 'Financial Situation'
# ...

# %% [markdown]
# Main Categories (主要类别): 描述 ACORN 分组的主要类别，如人口、住房、经济等。
# POPULATION (人口): 包含年龄、性别、人口密度等基本人口统计信息。
# HOUSING (住房): 描述住宅类型、居住条件、房屋所有权等住房相关数据。
# FAMILY (家庭): 涵盖家庭结构、家庭大小、婚姻状况等信息。
# ECONOMY (经济): 包括就业率、行业分布、收入水平等经济活动和特征。
# EDUCATION (教育): 教育水平、在校学生人数、教育机构分布等教育相关数据。
# HEALTH (健康): 医疗设施可达性、健康状况指标、疾病发病率等健康信息。
# TRANSPORT (交通): 交通方式、通勤时间、公共交通可用性等交通情况。
# MARKETING CHANNELS (营销渠道): 消费者获取信息和购买产品的渠道，如社交媒体、传统媒体等。
# FINANCE (财务): 描述信用状况、投资偏好、银行服务使用等财务行为。
# DIGITAL (数字): 网络使用习惯、电子设备拥有率、数字技能等数字化生活方面的数据​​。
# SHOPPING (购物): 购物行为、消费偏好、购买力等消费者购物相关信息。
# CONTACT (联系): 社交互动、社区参与、通讯方式等社会联系方式。
# ENVIRONMENT (环境): 环境质量、绿地覆盖率、污染水平等环境状况。
# COMMUNITY SAFETY (社区安全): 犯罪率、公共安全感知、紧急服务可达性等社区安全信息。
# LEISURE TIME (休闲时间): 休闲活动、娱乐偏好、休闲设施使用等闲暇时间如何度过的数据。
#
# Categories (类别): 描述 ACORN 分组的具体类别，如年龄段、家庭类型、收入水平等。
# Age, Geography, Ethnicity, Country of Birth, Religion 等列关注基本人口统计信息，如年龄、居住地理位置、种族背景、出生国家和宗教信仰，这些是了解一个人口集合基本属性的关键因素。
#
# House Type, House Tenure, House Size, House Value 和 Moving House 则提供有关居住环境的详细信息，包括住房类型、拥有权情况、房屋大小、估值以及是否近期搬家等。
#
# Economic Activity, NS Socio-Economic Classifications, Social Grade, Occupation 以及 Household Annual Income 等列涵盖经济活动和社会经济地位，聚焦于职业、收入水平以及社会等级划分。
#
# Highest Level of Qualifications (Adults) 和关于英格兰与苏格兰学生学业成绩的列（如 England: Pupils at the end of KS1）提供教育水平和学业成就的数据。
#
# Behaviours & Lifestyle 包括旅行、公共交通可及性、汽车拥有情况等生活方式和行为习惯的信息。
#
# Financial Attitudes, Financial Situation, Benefits, Credit Cards, Savings and Investments, Loans 以及 Insurance and Pensions 等列关注个人或家庭的财务状况和态度，包括信用卡使用、储蓄投资情况、贷款以及保险和养老金情况。
#
# Digital Attitudes, Technology at Home, Internet Access, Social Media Activity 等列探索数字技术使用情况和互联网行为，包括家庭中的技术设备、互联网接入频率以及社交媒体使用情况。
#
# Food Shopping, Clothing & Footwear Stores, Furniture & Fittings Stores 等列则提供消费行为和购物偏好的洞察，涉及食品购物、衣物鞋类和家具家装的购买地点选择。
#
# Environmental Groups, Action, Attitude 列提供有关环境观念和行动的信息，反映个人或社区对环保议题的态度和参与程度。
#
# Crime Survey for England, Daily Newspapers, Magazines Read, Charities, Books Read, Interests & Hobbies 等列提供更为细致的生活方式、媒体消费习惯、兴趣爱好以及社会参与等信息
#
# reference(参考）
#
# 人口统计特征
# Age 0-4, Age 5-17, 等：特定年龄段的人口。
# England, Northern Ireland, Scotland, Wales：居住地区域。
# White, Mixed, Asian, Black, Other ethnicity：种族背景。
# UK / ROI, EU: Member countries in March 2001, 等：出生地区域，包括英国、爱尔兰共和国、欧盟成员国等。
# Christian, Jewish, Buddhist, Muslim, Hindu, Sikh, Other religion：宗教信仰。
# 居住环境
# Bungalow, Detached house, Flat or maisonette, 等：住宅类型。
# Owner occupied, Owned outright, Mortgaged, 等：住房拥有权情况。
# Number of Beds : 1, Number of Beds : 2, 等：房屋床位数。
# House Value up to 100k, House Value 100k-150k, 等：房屋价值。
# 家庭和社会经济地位
# Couple family no children, Couple family with dependent children, 等：家庭类型。
# Employee Full-Time, Employee Part-Time, Self-employed, 等：经济活动状况。
# Higher managerial, Lower managerial, Intermediate occupations, 等：社会经济分类。
# A, B, C1, C2, D, E：社会等级。
# 教育和技能
# No formal qualifications, GCSE / O levels / CSE, 等：最高教育水平。
# Achieving expected level in reading, writing, 等：在特定教育阶段达到的预期学习水平。
# 生活方式和消费行为
# Current cigarette smoker, Takes regular exercise：生活习惯和行为。
# Train / Tube / Tram, Car, van or motorbike, 等：上班通勤方式。
# Number of Cars 0, Number of Cars 1, 等：汽车拥有数量。
# Food Shopping, Clothing & Footwear Stores, 等：购物偏好。
# 金融和消费
# Household Annual Income, Financial Attitudes, Financial Situation, 等：家庭年收入、金融态度和财务状况。
# Savings and Investments, Loans, Insurance and Pensions：储蓄投资、贷款以及保险和养老金。
# 数字和技术
# Internet Access: Frequency, Digital Attitudes, Technology at Home, 等：互联网使用频率、数字态度和家中技术设备。
# Social Media Activity (at least weekly), Social Media Brands (used at least weekly), 等：社交媒体活动和常用平台。

# %%
# uk_bank_holidays.csv : 包含英国银行假日的数据
uk_bank_holidays = pd.read_csv('archive/uk_bank_holidays.csv')
uk_bank_holidays
# Out:
#    Bank holidays                                          Type
# 0     2012-12-26                                    Boxing Day
# 1     2012-12-25                                 Christmas Day
# 2     2012-08-27                           Summer bank holiday
# 3     2012-05-06  Queen?s Diamond Jubilee (extra bank holiday)
# 4     2012-04-06          Spring bank holiday (substitute day)
# 5     2012-07-05                        Early May bank holiday
# 6     2012-09-04                                 Easter Monday
# 7     2012-06-04                                   Good Friday
# 8     2012-02-01               New Year?s Day (substitute day)
# 9     2013-12-26                                    Boxing Day
# 10    2013-12-25                                 Christmas Day
# 11    2013-08-26                           Summer bank holiday
# 12    2013-05-27                           Spring bank holiday
# 13    2013-06-05                        Early May bank holiday
# ...

# %%
uk_bank_holidays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Bank holidays  25 non-null     object
#  1   Type           25 non-null     object
# dtypes: object(2)
# memory usage: 528.0+ bytes

# %%
# weather_daily_darksky.csv : 包含来自 darksky api 的每日数据。有关参数的更多详情，请参阅 api 文档
weather_daily_darksky = pd.read_csv('archive/weather_daily_darksky.csv')
weather_daily_darksky
# Out:
#      temperatureMax   temperatureMaxTime  windBearing                 icon  \
# 0             11.96  2011-11-11 23:00:00          123                  fog
# 1              8.59  2011-12-11 14:00:00          198    partly-cloudy-day
# 2             10.33  2011-12-27 02:00:00          225    partly-cloudy-day
# 3              8.07  2011-12-02 23:00:00          232                 wind
# 4              8.22  2011-12-24 23:00:00          252  partly-cloudy-night
# ..              ...                  ...          ...                  ...
# 877            9.03  2014-01-26 16:00:00          233    partly-cloudy-day
# 878           10.31  2014-02-27 14:00:00          224    partly-cloudy-day
# 879           18.97  2014-03-09 14:00:00          172  partly-cloudy-night
# 880            8.83  2014-02-12 16:00:00          210                 wind
# 881            9.90  2014-02-15 12:00:00          233                 wind
#
# ...

# %%
weather_daily_darksky.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882 entries, 0 to 881
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   temperatureMax               882 non-null    float64
#  1   temperatureMaxTime           882 non-null    object
#  2   windBearing                  882 non-null    int64
#  3   icon                         882 non-null    object
#  4   dewPoint                     882 non-null    float64
#  5   temperatureMinTime           882 non-null    object
#  6   cloudCover                   881 non-null    float64
#  7   windSpeed                    882 non-null    float64
#  8   pressure                     882 non-null    float64
#  9   apparentTemperatureMinTime   882 non-null    object
#  10  apparentTemperatureHigh      882 non-null    float64
#  11  precipType                   882 non-null    object
#  12  visibility                   882 non-null    float64
# ...

# %%
print(weather_daily_darksky.columns.tolist())
# Out:
# ['temperatureMax', 'temperatureMaxTime', 'windBearing', 'icon', 'dewPoint', 'temperatureMinTime', 'cloudCover', 'windSpeed', 'pressure', 'apparentTemperatureMinTime', 'apparentTemperatureHigh', 'precipType', 'visibility', 'humidity', 'apparentTemperatureHighTime', 'apparentTemperatureLow', 'apparentTemperatureMax', 'uvIndex', 'time', 'sunsetTime', 'temperatureLow', 'temperatureMin', 'temperatureHigh', 'sunriseTime', 'temperatureHighTime', 'uvIndexTime', 'summary', 'temperatureLowTime', 'apparentTemperatureMin', 'apparentTemperatureMaxTime', 'apparentTemperatureLowTime', 'moonPhase']

# %% [markdown]
# ['temperatureMax', 'temperatureMaxTime', 'windBearing', 'icon', 'dewPoint', 'temperatureMinTime', 'cloudCover', 'windSpeed', 'pressure', 'apparentTemperatureMinTime', 'apparentTemperatureHigh', 'precipType', 'visibility', 'humidity', 'apparentTemperatureHighTime', 'apparentTemperatureLow', 'apparentTemperatureMax', 'uvIndex', 'time', 'sunsetTime', 'temperatureLow', 'temperatureMin', 'temperatureHigh', 'sunriseTime', 'temperatureHighTime', 'uvIndexTime', 'summary', 'temperatureLowTime', 'apparentTemperatureMin', 'apparentTemperatureMaxTime', 'apparentTemperatureLowTime', 'moonPhase']
# temperatureMax - 当天的最高气温。
# temperatureMaxTime - 最高气温发生的时间。
# windBearing - 风向，表示风从哪个方向吹来，通常以角度表示。
# icon - 天气情况的图标代码，如晴天、多云等。
# dewPoint - 露点温度，表示空气达到饱和（露水开始凝结）的温度。
# temperatureMinTime - 最低气温发生的时间。
# cloudCover - 云量，表示天空被云层覆盖的比例。
# windSpeed - 风速。
# pressure - 大气压强。
# apparentTemperatureMinTime - 体感最低温度发生的时间。
# apparentTemperatureHigh - 当天的最高体感温度。
# precipType - 降水类型，如雨、雪。
# visibility - 能见度。
# humidity - 湿度。
# apparentTemperatureHighTime - 最高体感温度发生的时间。
# apparentTemperatureLow - 当天的最低体感温度。
# apparentTemperatureMax - 当天的最高体感温度。
# uvIndex - 紫外线指数。
# time - 观测时间。
# sunsetTime - 日落时间。
# temperatureLow - 当天的最低气温。
# temperatureMin - 同temperatureLow，当天的最低气温。
# temperatureHigh - 当天的最高气温。
# sunriseTime - 日出时间。
# temperatureHighTime - 最高气温发生的时间。
# uvIndexTime - 紫外线指数达到最高点的时间。
# summary - 天气概况的文字描述。
# temperatureLowTime - 最低气温发生的时间。
# apparentTemperatureMin - 当天的最低体感温度。
# apparentTemperatureMaxTime - 最高体感温度发生的时间。
# apparentTemperatureLowTime - 最低体感温度发生的时间。
# moonPhase - 月相。

# %%
# weather_hourly_darksky.csv : 包含来自 darksky api 的每小时数据。有关参数的更多详情，请参阅 api 文档。
weather_hourly_darksky = pd.read_csv('archive/weather_hourly_darksky.csv')
weather_hourly_darksky
# Out:
#        visibility  windBearing  temperature                 time  dewPoint  \
# 0            5.97          104        10.24  2011-11-11 00:00:00      8.86
# 1            4.88           99         9.76  2011-11-11 01:00:00      8.83
# 2            3.70           98         9.46  2011-11-11 02:00:00      8.79
# 3            3.12           99         9.23  2011-11-11 03:00:00      8.63
# 4            1.85          111         9.26  2011-11-11 04:00:00      9.21
# ...           ...          ...          ...                  ...       ...
# 21160       12.68          247         7.39  2014-02-15 19:00:00      3.06
# 21161       13.78          249         6.56  2014-02-15 20:00:00      2.76
# 21162       14.31          248         6.47  2014-02-15 21:00:00      2.71
# 21163       14.31          248         5.96  2014-02-15 22:00:00      2.69
# 21164       14.31          246         5.38  2014-02-15 23:00:00      2.60
#
#        pressure  apparentTemperature  windSpeed precipType  \
# ...

# %%
print(weather_hourly_darksky.columns.tolist())
# Out:
# ['visibility', 'windBearing', 'temperature', 'time', 'dewPoint', 'pressure', 'apparentTemperature', 'windSpeed', 'precipType', 'icon', 'humidity', 'summary']

# %% [markdown]
# ['visibility', 'windBearing', 'temperature', 'time', 'dewPoint', 'pressure', 'apparentTemperature', 'windSpeed', 'precipType', 'icon', 'humidity', 'summary']
# visibility - 能见度，通常以公里或英里为单位，表示在特定天气条件下最远可见的距离。
# windBearing - 风向，表示风从哪个方向吹来。通常以角度表示，其中0度代表北风，90度代表东风，180度代表南风，270度代表西风。
# temperature - 气温，通常以摄氏度或华氏度为单位，表示空气的热度。
# time - 时间，数据采集的具体时间点，通常以UNIX时间戳或可读格式表示。
# dewPoint - 露点温度，当空气冷却到无法容纳其中所有水蒸气时，水蒸气凝结成露水的温度。
# pressure - 大气压强，表示空气的重量压在地面上的力量，通常以百帕斯卡（hPa）或毫巴（mb）为单位。
# apparentTemperature - 体感温度，综合考虑风速、湿度和实际气温对人体感知温度的影响。
# windSpeed - 风速，表示风的快慢，通常以每秒米数或每小时英里数表示。
# precipType - 降水类型，如雨、雪、冰雹等。
# icon - 天气图标的标识，用于直观表示天气状况，如晴天、多云、雨天等。
# humidity - 湿度，表示空气中水蒸气的含量，通常以百分比表示。
# summary - 天气概况的文字描述，提供对当前或预测天气状况的简短总结。

# %%
print(weather_hourly_darksky.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21165 entries, 0 to 21164
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   visibility           21165 non-null  float64
#  1   windBearing          21165 non-null  int64
#  2   temperature          21165 non-null  float64
#  3   time                 21165 non-null  object
#  4   dewPoint             21165 non-null  float64
#  5   pressure             21152 non-null  float64
#  6   apparentTemperature  21165 non-null  float64
#  7   windSpeed            21165 non-null  float64
#  8   precipType           21165 non-null  object
#  9   icon                 21165 non-null  object
#  10  humidity             21165 non-null  float64
#  11  summary              21165 non-null  object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.9+ MB
# None
